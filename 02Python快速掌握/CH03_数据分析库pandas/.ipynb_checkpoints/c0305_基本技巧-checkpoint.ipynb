# %% [markdown]
# 数据查看、转置 / 添加、修改、删除值 / 对齐 / 排序

# %%
import numpy as np
import pandas as pd

# 导入numpy、pandas模块

# %%
# 数据查看、转置

df = pd.DataFrame(np.random.rand(16).reshape(8,2)*100,
                   columns = ['a','b'])
print(df)
print(df.head(2))
print(df.tail(2))
# .head()查看头部数据
# .tail()查看尾部数据
# 不传参默认查看5条

print(df.T)
# .T 转置
# Out:
#            a          b
# 0  14.597433  71.142430
# 1  94.403973   9.963606
# 2  28.565707   4.187819
# 3  23.858662  95.656702
# 4  36.644738   4.486912
# 5  23.074524  73.592092
# 6   7.169409  78.533518
# 7  11.355895  76.359442
#            a          b
# 0  14.597433  71.142430
# 1  94.403973   9.963606
#            a          b
# 6   7.169409  78.533518
# 7  11.355895  76.359442
#            0          1          2          3          4          5  \
# a  14.597433  94.403973  28.565707  23.858662  36.644738  23.074524
# b  71.142430   9.963606   4.187819  95.656702   4.486912  73.592092
#
#            6          7
# a   7.169409  11.355895
# b  78.533518  76.359442

# %%
# 添加与修改

df = pd.DataFrame(np.random.rand(16).reshape(4,4)*100,
                   columns = ['a','b','c','d'])
print(df)

df['e'] = 10
df.loc[4] = 20
print(df)
# 新增列/行并赋值

df['e'] = 20
df[['a','c']] = 100
print(df)
# 索引后直接修改值
# Out:
#            a          b          c          d
# 0  74.420715  54.474793  91.604974  91.459932
# 1  40.643011  31.162744  40.218124  26.364723
# 2  42.298198  83.902961  67.777314   3.131668
# 3  23.173671  45.450344  84.154241  68.397147
#            a          b          c          d   e
# 0  74.420715  54.474793  91.604974  91.459932  10
# 1  40.643011  31.162744  40.218124  26.364723  10
# 2  42.298198  83.902961  67.777314   3.131668  10
# 3  23.173671  45.450344  84.154241  68.397147  10
# 4  20.000000  20.000000  20.000000  20.000000  20
#      a          b    c          d   e
# 0  100  54.474793  100  91.459932  20
# 1  100  31.162744  100  26.364723  20
# 2  100  83.902961  100   3.131668  20
# 3  100  45.450344  100  68.397147  20
# 4  100  20.000000  100  20.000000  20

# %%
# 删除  del / drop()

df = pd.DataFrame(np.random.rand(16).reshape(4,4)*100,
                   columns = ['a','b','c','d'])
print(df)
print('----------------------------------------')

del df['a']
print(df)
print('----------------------------------------')
# del语句 - 删除列

print(df.drop(0))
print(df.drop([1,2]))
print(df)
print('----------------------------------------')
# drop()删除行，inplace=False → 删除后生成新的数据，不改变原数据

print(df.drop(['d'], axis = 1))
print(df)
# drop()删除列，需要加上axis = 1，inplace=False → 删除后生成新的数据，不改变原数据
# Out:
#            a          b          c          d
# 0  14.090932  71.560836  55.195017  46.152988
# 1  44.268478  64.640777   2.178977  79.514237
# 2  18.890485  92.171050  89.353562  69.759499
# 3  58.815334  11.175008  47.794309  27.747284
# ----------------------------------------
#            b          c          d
# 0  71.560836  55.195017  46.152988
# 1  64.640777   2.178977  79.514237
# 2  92.171050  89.353562  69.759499
# 3  11.175008  47.794309  27.747284
# ----------------------------------------
#            b          c          d
# 1  64.640777   2.178977  79.514237
# 2  92.171050  89.353562  69.759499
# 3  11.175008  47.794309  27.747284
#            b          c          d
# 0  71.560836  55.195017  46.152988
# 3  11.175008  47.794309  27.747284
#            b          c          d
# 0  71.560836  55.195017  46.152988
# 1  64.640777   2.178977  79.514237
# 2  92.171050  89.353562  69.759499
# 3  11.175008  47.794309  27.747284
# -----------------------------------
#            b          c
# 0  71.560836  55.195017
# 1  64.640777   2.178977
# 2  92.171050  89.353562
# 3  11.175008  47.794309
#            b          c          d
# 0  71.560836  55.195017  46.152988
# 1  64.640777   2.178977  79.514237
# 2  92.171050  89.353562  69.759499
# 3  11.175008  47.794309  27.747284

# %%
# 对齐

df1 = pd.DataFrame(np.random.randn(10, 4), columns=['A', 'B', 'C', 'D'])
print(df1)
print('----------------------------------------')
df2 = pd.DataFrame(np.random.randn(7, 3), columns=['A', 'B', 'C'])
print(df2)
print('----------------------------------------')
print(df1 + df2)
# DataFrame对象之间的数据自动按照列和索引（行标签）对齐
# Out:
#           A         B         C         D
# 0 -0.639107 -0.498374 -1.729619  0.280375
# 1 -0.504247 -0.771575 -0.413686 -0.615632
# 2  0.070884  1.854822  0.800740  0.587182
# 3  1.153863  0.934605  0.233261  1.193458
# 4 -0.239372 -0.458250  0.113092  0.054023
# 5 -0.765819  0.102862  0.428522 -1.323073
# 6  1.008476 -0.792582  0.146665 -0.063891
# 7  0.151933  1.659803 -0.958687 -0.994645
# 8 -0.608404  1.014335  0.203520 -1.337043
# 9 -1.941571  1.567050  0.871310  0.529357
# ----------------------------------------
#           A         B         C
# 0  0.518656  0.294592  0.413634
# 1  0.868094  0.286645  0.757999
# 2 -1.622570 -0.768239  0.058302
# 3  0.292287 -0.117009  1.056159
# 4  1.483484 -1.692797  1.546771
# 5  1.182100  0.836336  0.222707
# 6  0.434593  0.266910  0.168691
# ----------------------------------------
#           A         B         C   D
# 0 -0.120452 -0.203782 -1.315985 NaN
# 1  0.363847 -0.484929  0.344313 NaN
# 2 -1.551687  1.086583  0.859041 NaN
# 3  1.446150  0.817596  1.289420 NaN
# 4  1.244112 -2.151047  1.659864 NaN
# 5  0.416281  0.939198  0.651228 NaN
# 6  1.443069 -0.525673  0.315356 NaN
# 7       NaN       NaN       NaN NaN
# 8       NaN       NaN       NaN NaN
# 9       NaN       NaN       NaN NaN

# %%
# 排序1 - 按值排序 .sort_values
# 同样适用于Series

df1 = pd.DataFrame(np.random.rand(16).reshape(4,4)*100,
                   columns = ['a','b','c','d'])
print(df1)
print('------------------------------------------------')
print(df1.sort_values(['a'], ascending = True))  # 升序
print('-----------------------------------------------')
print(df1.sort_values(['a'], ascending = False))  # 降序
print('-----------------------------------------------')
# ascending参数：设置升序降序，默认升序
# 单列排序

df2 = pd.DataFrame({'a':[1,1,1,1,2,2,2,2],
                  'b':list(range(8)),
                  'c':list(range(8,0,-1))})
print(df2)
print('--------------------------------------------')
print(df2.sort_values(['a','c']))
# 多列排序，按列顺序排序
# 注意inplace参数
# Out:
#            a          b          c          d
# 0  62.816075  67.646447   1.983008  98.850396
# 1  48.133189  90.383754  23.174364  33.570298
# 2  78.122987   6.652456  70.694155  46.504340
# 3  33.279795  95.488333   6.583659  20.343426
# ------------------------------------------------
#            a          b          c          d
# 3  33.279795  95.488333   6.583659  20.343426
# 1  48.133189  90.383754  23.174364  33.570298
# 0  62.816075  67.646447   1.983008  98.850396
# 2  78.122987   6.652456  70.694155  46.504340
# -----------------------------------------------
#            a          b          c          d
# 2  78.122987   6.652456  70.694155  46.504340
# 0  62.816075  67.646447   1.983008  98.850396
# 1  48.133189  90.383754  23.174364  33.570298
# 3  33.279795  95.488333   6.583659  20.343426
# -----------------------------------------------
#    a  b  c
# 0  1  0  8
# 1  1  1  7
# 2  1  2  6
# 3  1  3  5
# 4  2  4  4
# 5  2  5  3
# 6  2  6  2
# 7  2  7  1
# --------------------------------------------
#    a  b  c
# 3  1  3  5
# 2  1  2  6
# 1  1  1  7
# 0  1  0  8
# 7  2  7  1
# 6  2  6  2
# 5  2  5  3
# 4  2  4  4

# %%
# 排序2 - 索引排序 .sort_index

df1 = pd.DataFrame(np.random.rand(16).reshape(4,4)*100,
                  index = [5,4,3,2],
                   columns = ['a','b','c','d'])
df2 = pd.DataFrame(np.random.rand(16).reshape(4,4)*100,
                  index = ['h','s','x','g'],
                   columns = ['a','b','c','d'])
print(df1)
print('------------------------------------------------')
print(df1.sort_index())
print('------------------------------------------------')
print(df2)
print('------------------------------------------------')
print(df2.sort_index())
# 按照index排序
# 默认 ascending=True, inplace=False
# Out:
#            a          b          c          d
# 5  76.775244  58.467086  21.704824  30.258725
# 4  27.370843  99.879374  58.698276  66.466787
# 3  46.003946  30.841545  33.562515  72.903835
# 2   4.841294  97.614744  40.590444  81.455196
# ------------------------------------------------
#            a          b          c          d
# 2   4.841294  97.614744  40.590444  81.455196
# 3  46.003946  30.841545  33.562515  72.903835
# 4  27.370843  99.879374  58.698276  66.466787
# 5  76.775244  58.467086  21.704824  30.258725
# ------------------------------------------------
#            a          b          c          d
# h  13.979515  29.962663  18.257082  70.633428
# s  24.185473  55.587362  95.145990  60.162313
# x  82.485956  54.335406  62.606309  57.443811
# g  71.843693  73.230981  64.889052  91.210671
# ------------------------------------------------
#            a          b          c          d
# g  71.843693  73.230981  64.889052  91.210671
# h  13.979515  29.962663  18.257082  70.633428
# s  24.185473  55.587362  95.145990  60.162313
# x  82.485956  54.335406  62.606309  57.443811

# %% [markdown]
# ######## 课后小练习,请查看 “pandas课程作业.docx”  ########
#
# 作业1：创建一个3*3，值在0-100区间随机值的Dataframe（如图），分别按照index和第二列值大小，降序排序
#
# 作业2：创建一个5*2，值在0-100区间随机值的Dataframe（如图）df1，通过修改得到df2
#
# 作业3：如图创建Series，并按照要求修改得到结果
#
# 作业4：已有s1，s2（值为0-10的随机数），请求出s1+s2的值
# * s1 = pd.Series(np.random.rand(5)*10,index = list('abcde'))
# * s2 = pd.Series(np.random.rand(5)*10,index = list('cdefg'))
