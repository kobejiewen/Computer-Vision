# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline
# 导入模块

import warnings
warnings.filterwarnings('ignore') 
# 不发出警告

# %% [markdown]
# 1.2.1 导数

# %%
# 直线运动问题
# 对于f(X) = x**2

def f(x):
    return x**2

plt.figure(figsize = (12,6))
n = np.linspace(-10,10,num = 50)
plt.plot(n,f(n))
plt.xlim(-11,11)
plt.ylim(-10,110)

# 选中曲线上两个点，m(2,4)，n(5,25)
plt.plot([2,5],[4,25],color = 'r')
print('直线斜率为%.2f' % ((25-4)/(5-2)))
print('-------')
# Out:
# 直线斜率为7.00
# -------

# %%
# 求m的导数

x_m = 2
y_m = f(x_m)
plt.plot(n,f(n))
plt.xlim(1,7)
plt.ylim(1,49)

for i in range(4,0,-1):
    plt.plot([x_m,x_m + i],[y_m,f(x_m + i)],color = 'r')
    print('直线斜率为%.2f' % ((f(x_m + i)-y_m)/(x_m + i-x_m)))

# f(x) = x**2
# 原始点 m,f(m)
# 增量为i,直线终点 → m+i,f(m+i)
# 斜率 → (f(m+i)-f(m))/i
# Out:
# 直线斜率为8.00
# 直线斜率为7.00
# 直线斜率为6.00
# 直线斜率为5.00

# %%
def ds(xm,n):
    '''
    该函数为求f(x) = x**2的导数
    xm：m点的x值
    n：m点x往右偏移的距离
    函数最后导出 → m点与m偏移n距离后点的连线的斜率
    '''
    y1 = f(xm)
    y2 = f(xm+n)
    return (y2-y1)/n

for i in np.linspace(1,0,num = 1000,endpoint = False):
    print('偏移%.2f个单位距离时，斜率为：%.5f' % (i,ds(2,i)))
# 斜率为4
# 切线函数为：y = 4*x - 4
# Out:
# 偏移1.00个单位距离时，斜率为：5.00000
# 偏移1.00个单位距离时，斜率为：4.99900
# 偏移1.00个单位距离时，斜率为：4.99800
# 偏移1.00个单位距离时，斜率为：4.99700
# 偏移1.00个单位距离时，斜率为：4.99600
# 偏移0.99个单位距离时，斜率为：4.99500
# 偏移0.99个单位距离时，斜率为：4.99400
# 偏移0.99个单位距离时，斜率为：4.99300
# 偏移0.99个单位距离时，斜率为：4.99200
# 偏移0.99个单位距离时，斜率为：4.99100
# 偏移0.99个单位距离时，斜率为：4.99000
# 偏移0.99个单位距离时，斜率为：4.98900
# 偏移0.99个单位距离时，斜率为：4.98800
# 偏移0.99个单位距离时，斜率为：4.98700
# 偏移0.99个单位距离时，斜率为：4.98600
# 偏移0.98个单位距离时，斜率为：4.98500
# 偏移0.98个单位距离时，斜率为：4.98400
# 偏移0.98个单位距离时，斜率为：4.98300
# 偏移0.98个单位距离时，斜率为：4.98200
# 偏移0.98个单位距离时，斜率为：4.98100
# 偏移0.98个单位距离时，斜率为：4.98000
# 偏移0.98个单位距离时，斜率为：4.97900
# 偏移0.98个单位距离时，斜率为：4.97800
# 偏移0.98个单位距离时，斜率为：4.97700
# 偏移0.98个单位距离时，斜率为：4.97600
# 偏移0.97个单位距离时，斜率为：4.97500
# 偏移0.97个单位距离时，斜率为：4.97400
# 偏移0.97个单位距离时，斜率为：4.97300
# 偏移0.97个单位距离时，斜率为：4.97200
# 偏移0.97个单位距离时，斜率为：4.97100
# 偏移0.97个单位距离时，斜率为：4.97000
# 偏移0.97个单位距离时，斜率为：4.96900
# 偏移0.97个单位距离时，斜率为：4.96800
# 偏移0.97个单位距离时，斜率为：4.96700
# 偏移0.97个单位距离时，斜率为：4.96600
# 偏移0.96个单位距离时，斜率为：4.96500
# 偏移0.96个单位距离时，斜率为：4.96400
# 偏移0.96个单位距离时，斜率为：4.96300
# 偏移0.96个单位距离时，斜率为：4.96200
# 偏移0.96个单位距离时，斜率为：4.96100
# 偏移0.96个单位距离时，斜率为：4.96000
# 偏移0.96个单位距离时，斜率为：4.95900
# 偏移0.96个单位距离时，斜率为：4.95800
# 偏移0.96个单位距离时，斜率为：4.95700
# 偏移0.96个单位距离时，斜率为：4.95600
# 偏移0.95个单位距离时，斜率为：4.95500
# 偏移0.95个单位距离时，斜率为：4.95400
# 偏移0.95个单位距离时，斜率为：4.95300
# 偏移0.95个单位距离时，斜率为：4.95200
# 偏移0.95个单位距离时，斜率为：4.95100
# 偏移0.95个单位距离时，斜率为：4.95000
# 偏移0.95个单位距离时，斜率为：4.94900
# 偏移0.95个单位距离时，斜率为：4.94800
# 偏移0.95个单位距离时，斜率为：4.94700
# 偏移0.95个单位距离时，斜率为：4.94600
# 偏移0.94个单位距离时，斜率为：4.94500
# 偏移0.94个单位距离时，斜率为：4.94400
# 偏移0.94个单位距离时，斜率为：4.94300
# 偏移0.94个单位距离时，斜率为：4.94200
# 偏移0.94个单位距离时，斜率为：4.94100
# 偏移0.94个单位距离时，斜率为：4.94000
# 偏移0.94个单位距离时，斜率为：4.93900
# 偏移0.94个单位距离时，斜率为：4.93800
# 偏移0.94个单位距离时，斜率为：4.93700
# 偏移0.94个单位距离时，斜率为：4.93600
# 偏移0.94个单位距离时，斜率为：4.93500
# 偏移0.93个单位距离时，斜率为：4.93400
# 偏移0.93个单位距离时，斜率为：4.93300
# 偏移0.93个单位距离时，斜率为：4.93200
# 偏移0.93个单位距离时，斜率为：4.93100
# 偏移0.93个单位距离时，斜率为：4.93000
# 偏移0.93个单位距离时，斜率为：4.92900
# 偏移0.93个单位距离时，斜率为：4.92800
# 偏移0.93个单位距离时，斜率为：4.92700
# 偏移0.93个单位距离时，斜率为：4.92600
# 偏移0.93个单位距离时，斜率为：4.92500
# 偏移0.92个单位距离时，斜率为：4.92400
# 偏移0.92个单位距离时，斜率为：4.92300
# 偏移0.92个单位距离时，斜率为：4.92200
# 偏移0.92个单位距离时，斜率为：4.92100
# 偏移0.92个单位距离时，斜率为：4.92000
# 偏移0.92个单位距离时，斜率为：4.91900
# 偏移0.92个单位距离时，斜率为：4.91800
# 偏移0.92个单位距离时，斜率为：4.91700
# 偏移0.92个单位距离时，斜率为：4.91600
# 偏移0.92个单位距离时，斜率为：4.91500
# 偏移0.91个单位距离时，斜率为：4.91400
# 偏移0.91个单位距离时，斜率为：4.91300
# 偏移0.91个单位距离时，斜率为：4.91200
# 偏移0.91个单位距离时，斜率为：4.91100
# 偏移0.91个单位距离时，斜率为：4.91000
# 偏移0.91个单位距离时，斜率为：4.90900
# 偏移0.91个单位距离时，斜率为：4.90800
# 偏移0.91个单位距离时，斜率为：4.90700
# 偏移0.91个单位距离时，斜率为：4.90600
# 偏移0.91个单位距离时，斜率为：4.90500
# 偏移0.90个单位距离时，斜率为：4.90400
# 偏移0.90个单位距离时，斜率为：4.90300
# 偏移0.90个单位距离时，斜率为：4.90200
# 偏移0.90个单位距离时，斜率为：4.90100
# 偏移0.90个单位距离时，斜率为：4.90000
# 偏移0.90个单位距离时，斜率为：4.89900
# 偏移0.90个单位距离时，斜率为：4.89800
# 偏移0.90个单位距离时，斜率为：4.89700
# 偏移0.90个单位距离时，斜率为：4.89600
# 偏移0.90个单位距离时，斜率为：4.89500
# 偏移0.89个单位距离时，斜率为：4.89400
# 偏移0.89个单位距离时，斜率为：4.89300
# 偏移0.89个单位距离时，斜率为：4.89200
# 偏移0.89个单位距离时，斜率为：4.89100
# 偏移0.89个单位距离时，斜率为：4.89000
# 偏移0.89个单位距离时，斜率为：4.88900
# 偏移0.89个单位距离时，斜率为：4.88800
# 偏移0.89个单位距离时，斜率为：4.88700
# 偏移0.89个单位距离时，斜率为：4.88600
# 偏移0.89个单位距离时，斜率为：4.88500
# 偏移0.88个单位距离时，斜率为：4.88400
# 偏移0.88个单位距离时，斜率为：4.88300
# 偏移0.88个单位距离时，斜率为：4.88200
# 偏移0.88个单位距离时，斜率为：4.88100
# 偏移0.88个单位距离时，斜率为：4.88000
# 偏移0.88个单位距离时，斜率为：4.87900
# 偏移0.88个单位距离时，斜率为：4.87800
# 偏移0.88个单位距离时，斜率为：4.87700
# 偏移0.88个单位距离时，斜率为：4.87600
# 偏移0.88个单位距离时，斜率为：4.87500
# 偏移0.87个单位距离时，斜率为：4.87400
# 偏移0.87个单位距离时，斜率为：4.87300
# 偏移0.87个单位距离时，斜率为：4.87200
# 偏移0.87个单位距离时，斜率为：4.87100
# 偏移0.87个单位距离时，斜率为：4.87000
# 偏移0.87个单位距离时，斜率为：4.86900
# 偏移0.87个单位距离时，斜率为：4.86800
# 偏移0.87个单位距离时，斜率为：4.86700
# 偏移0.87个单位距离时，斜率为：4.86600
# 偏移0.86个单位距离时，斜率为：4.86500
# 偏移0.86个单位距离时，斜率为：4.86400
# 偏移0.86个单位距离时，斜率为：4.86300
# 偏移0.86个单位距离时，斜率为：4.86200
# 偏移0.86个单位距离时，斜率为：4.86100
# 偏移0.86个单位距离时，斜率为：4.86000
# 偏移0.86个单位距离时，斜率为：4.85900
# 偏移0.86个单位距离时，斜率为：4.85800
# 偏移0.86个单位距离时，斜率为：4.85700
# 偏移0.86个单位距离时，斜率为：4.85600
# 偏移0.85个单位距离时，斜率为：4.85500
# 偏移0.85个单位距离时，斜率为：4.85400
# 偏移0.85个单位距离时，斜率为：4.85300
# 偏移0.85个单位距离时，斜率为：4.85200
# 偏移0.85个单位距离时，斜率为：4.85100
# 偏移0.85个单位距离时，斜率为：4.85000
# 偏移0.85个单位距离时，斜率为：4.84900
# 偏移0.85个单位距离时，斜率为：4.84800
# 偏移0.85个单位距离时，斜率为：4.84700
# 偏移0.85个单位距离时，斜率为：4.84600
# 偏移0.84个单位距离时，斜率为：4.84500
# 偏移0.84个单位距离时，斜率为：4.84400
# 偏移0.84个单位距离时，斜率为：4.84300
# 偏移0.84个单位距离时，斜率为：4.84200
# 偏移0.84个单位距离时，斜率为：4.84100
# 偏移0.84个单位距离时，斜率为：4.84000
# 偏移0.84个单位距离时，斜率为：4.83900
# 偏移0.84个单位距离时，斜率为：4.83800
# 偏移0.84个单位距离时，斜率为：4.83700
# 偏移0.84个单位距离时，斜率为：4.83600
# 偏移0.83个单位距离时，斜率为：4.83500
# 偏移0.83个单位距离时，斜率为：4.83400
# 偏移0.83个单位距离时，斜率为：4.83300
# 偏移0.83个单位距离时，斜率为：4.83200
# 偏移0.83个单位距离时，斜率为：4.83100
# 偏移0.83个单位距离时，斜率为：4.83000
# 偏移0.83个单位距离时，斜率为：4.82900
# 偏移0.83个单位距离时，斜率为：4.82800
# 偏移0.83个单位距离时，斜率为：4.82700
# 偏移0.83个单位距离时，斜率为：4.82600
# 偏移0.82个单位距离时，斜率为：4.82500
# 偏移0.82个单位距离时，斜率为：4.82400
# 偏移0.82个单位距离时，斜率为：4.82300
# 偏移0.82个单位距离时，斜率为：4.82200
# 偏移0.82个单位距离时，斜率为：4.82100
# 偏移0.82个单位距离时，斜率为：4.82000
# 偏移0.82个单位距离时，斜率为：4.81900
# 偏移0.82个单位距离时，斜率为：4.81800
# 偏移0.82个单位距离时，斜率为：4.81700
# 偏移0.82个单位距离时，斜率为：4.81600
# 偏移0.81个单位距离时，斜率为：4.81500
# 偏移0.81个单位距离时，斜率为：4.81400
# 偏移0.81个单位距离时，斜率为：4.81300
# 偏移0.81个单位距离时，斜率为：4.81200
# 偏移0.81个单位距离时，斜率为：4.81100
# 偏移0.81个单位距离时，斜率为：4.81000
# 偏移0.81个单位距离时，斜率为：4.80900
# 偏移0.81个单位距离时，斜率为：4.80800
# 偏移0.81个单位距离时，斜率为：4.80700
# 偏移0.81个单位距离时，斜率为：4.80600
# 偏移0.80个单位距离时，斜率为：4.80500
# 偏移0.80个单位距离时，斜率为：4.80400
# 偏移0.80个单位距离时，斜率为：4.80300
# 偏移0.80个单位距离时，斜率为：4.80200
# 偏移0.80个单位距离时，斜率为：4.80100
# 偏移0.80个单位距离时，斜率为：4.80000
# 偏移0.80个单位距离时，斜率为：4.79900
# 偏移0.80个单位距离时，斜率为：4.79800
# 偏移0.80个单位距离时，斜率为：4.79700
# 偏移0.80个单位距离时，斜率为：4.79600
# 偏移0.79个单位距离时，斜率为：4.79500
# 偏移0.79个单位距离时，斜率为：4.79400
# 偏移0.79个单位距离时，斜率为：4.79300
# 偏移0.79个单位距离时，斜率为：4.79200
# 偏移0.79个单位距离时，斜率为：4.79100
# 偏移0.79个单位距离时，斜率为：4.79000
# 偏移0.79个单位距离时，斜率为：4.78900
# 偏移0.79个单位距离时，斜率为：4.78800
# 偏移0.79个单位距离时，斜率为：4.78700
# 偏移0.79个单位距离时，斜率为：4.78600
# 偏移0.79个单位距离时，斜率为：4.78500
# 偏移0.78个单位距离时，斜率为：4.78400
# 偏移0.78个单位距离时，斜率为：4.78300
# 偏移0.78个单位距离时，斜率为：4.78200
# 偏移0.78个单位距离时，斜率为：4.78100
# 偏移0.78个单位距离时，斜率为：4.78000
# 偏移0.78个单位距离时，斜率为：4.77900
# 偏移0.78个单位距离时，斜率为：4.77800
# 偏移0.78个单位距离时，斜率为：4.77700
# 偏移0.78个单位距离时，斜率为：4.77600
# 偏移0.78个单位距离时，斜率为：4.77500
# 偏移0.77个单位距离时，斜率为：4.77400
# 偏移0.77个单位距离时，斜率为：4.77300
# 偏移0.77个单位距离时，斜率为：4.77200
# 偏移0.77个单位距离时，斜率为：4.77100
# 偏移0.77个单位距离时，斜率为：4.77000
# 偏移0.77个单位距离时，斜率为：4.76900
# 偏移0.77个单位距离时，斜率为：4.76800
# 偏移0.77个单位距离时，斜率为：4.76700
# 偏移0.77个单位距离时，斜率为：4.76600
# 偏移0.77个单位距离时，斜率为：4.76500
# 偏移0.76个单位距离时，斜率为：4.76400
# 偏移0.76个单位距离时，斜率为：4.76300
# 偏移0.76个单位距离时，斜率为：4.76200
# 偏移0.76个单位距离时，斜率为：4.76100
# 偏移0.76个单位距离时，斜率为：4.76000
# 偏移0.76个单位距离时，斜率为：4.75900
# 偏移0.76个单位距离时，斜率为：4.75800
# 偏移0.76个单位距离时，斜率为：4.75700
# 偏移0.76个单位距离时，斜率为：4.75600
# 偏移0.76个单位距离时，斜率为：4.75500
# 偏移0.75个单位距离时，斜率为：4.75400
# 偏移0.75个单位距离时，斜率为：4.75300
# 偏移0.75个单位距离时，斜率为：4.75200
# 偏移0.75个单位距离时，斜率为：4.75100
# 偏移0.75个单位距离时，斜率为：4.75000
# 偏移0.75个单位距离时，斜率为：4.74900
# 偏移0.75个单位距离时，斜率为：4.74800
# 偏移0.75个单位距离时，斜率为：4.74700
# 偏移0.75个单位距离时，斜率为：4.74600
# 偏移0.74个单位距离时，斜率为：4.74500
# 偏移0.74个单位距离时，斜率为：4.74400
# 偏移0.74个单位距离时，斜率为：4.74300
# 偏移0.74个单位距离时，斜率为：4.74200
# 偏移0.74个单位距离时，斜率为：4.74100
# 偏移0.74个单位距离时，斜率为：4.74000
# 偏移0.74个单位距离时，斜率为：4.73900
# 偏移0.74个单位距离时，斜率为：4.73800
# 偏移0.74个单位距离时，斜率为：4.73700
# 偏移0.74个单位距离时，斜率为：4.73600
# 偏移0.73个单位距离时，斜率为：4.73500
# 偏移0.73个单位距离时，斜率为：4.73400
# 偏移0.73个单位距离时，斜率为：4.73300
# 偏移0.73个单位距离时，斜率为：4.73200
# 偏移0.73个单位距离时，斜率为：4.73100
# 偏移0.73个单位距离时，斜率为：4.73000
# 偏移0.73个单位距离时，斜率为：4.72900
# 偏移0.73个单位距离时，斜率为：4.72800
# 偏移0.73个单位距离时，斜率为：4.72700
# 偏移0.73个单位距离时，斜率为：4.72600
# 偏移0.72个单位距离时，斜率为：4.72500
# 偏移0.72个单位距离时，斜率为：4.72400
# 偏移0.72个单位距离时，斜率为：4.72300
# 偏移0.72个单位距离时，斜率为：4.72200
# 偏移0.72个单位距离时，斜率为：4.72100
# 偏移0.72个单位距离时，斜率为：4.72000
# 偏移0.72个单位距离时，斜率为：4.71900
# 偏移0.72个单位距离时，斜率为：4.71800
# 偏移0.72个单位距离时，斜率为：4.71700
# 偏移0.72个单位距离时，斜率为：4.71600
# 偏移0.71个单位距离时，斜率为：4.71500
# 偏移0.71个单位距离时，斜率为：4.71400
# 偏移0.71个单位距离时，斜率为：4.71300
# 偏移0.71个单位距离时，斜率为：4.71200
# 偏移0.71个单位距离时，斜率为：4.71100
# 偏移0.71个单位距离时，斜率为：4.71000
# 偏移0.71个单位距离时，斜率为：4.70900
# 偏移0.71个单位距离时，斜率为：4.70800
# 偏移0.71个单位距离时，斜率为：4.70700
# 偏移0.71个单位距离时，斜率为：4.70600
# 偏移0.71个单位距离时，斜率为：4.70500
# 偏移0.70个单位距离时，斜率为：4.70400
# 偏移0.70个单位距离时，斜率为：4.70300
# 偏移0.70个单位距离时，斜率为：4.70200
# 偏移0.70个单位距离时，斜率为：4.70100
# 偏移0.70个单位距离时，斜率为：4.70000
# 偏移0.70个单位距离时，斜率为：4.69900
# 偏移0.70个单位距离时，斜率为：4.69800
# 偏移0.70个单位距离时，斜率为：4.69700
# 偏移0.70个单位距离时，斜率为：4.69600
# 偏移0.70个单位距离时，斜率为：4.69500
# 偏移0.69个单位距离时，斜率为：4.69400
# 偏移0.69个单位距离时，斜率为：4.69300
# 偏移0.69个单位距离时，斜率为：4.69200
# 偏移0.69个单位距离时，斜率为：4.69100
# 偏移0.69个单位距离时，斜率为：4.69000
# 偏移0.69个单位距离时，斜率为：4.68900
# 偏移0.69个单位距离时，斜率为：4.68800
# 偏移0.69个单位距离时，斜率为：4.68700
# 偏移0.69个单位距离时，斜率为：4.68600
# 偏移0.69个单位距离时，斜率为：4.68500
# 偏移0.68个单位距离时，斜率为：4.68400
# 偏移0.68个单位距离时，斜率为：4.68300
# 偏移0.68个单位距离时，斜率为：4.68200
# 偏移0.68个单位距离时，斜率为：4.68100
# 偏移0.68个单位距离时，斜率为：4.68000
# 偏移0.68个单位距离时，斜率为：4.67900
# 偏移0.68个单位距离时，斜率为：4.67800
# 偏移0.68个单位距离时，斜率为：4.67700
# 偏移0.68个单位距离时，斜率为：4.67600
# 偏移0.68个单位距离时，斜率为：4.67500
# 偏移0.67个单位距离时，斜率为：4.67400
# 偏移0.67个单位距离时，斜率为：4.67300
# 偏移0.67个单位距离时，斜率为：4.67200
# 偏移0.67个单位距离时，斜率为：4.67100
# 偏移0.67个单位距离时，斜率为：4.67000
# 偏移0.67个单位距离时，斜率为：4.66900
# 偏移0.67个单位距离时，斜率为：4.66800
# 偏移0.67个单位距离时，斜率为：4.66700
# 偏移0.67个单位距离时，斜率为：4.66600
# 偏移0.67个单位距离时，斜率为：4.66500
# 偏移0.66个单位距离时，斜率为：4.66400
# 偏移0.66个单位距离时，斜率为：4.66300
# 偏移0.66个单位距离时，斜率为：4.66200
# 偏移0.66个单位距离时，斜率为：4.66100
# 偏移0.66个单位距离时，斜率为：4.66000
# 偏移0.66个单位距离时，斜率为：4.65900
# 偏移0.66个单位距离时，斜率为：4.65800
# 偏移0.66个单位距离时，斜率为：4.65700
# 偏移0.66个单位距离时，斜率为：4.65600
# 偏移0.66个单位距离时，斜率为：4.65500
# 偏移0.65个单位距离时，斜率为：4.65400
# 偏移0.65个单位距离时，斜率为：4.65300
# 偏移0.65个单位距离时，斜率为：4.65200
# 偏移0.65个单位距离时，斜率为：4.65100
# 偏移0.65个单位距离时，斜率为：4.65000
# 偏移0.65个单位距离时，斜率为：4.64900
# 偏移0.65个单位距离时，斜率为：4.64800
# 偏移0.65个单位距离时，斜率为：4.64700
# 偏移0.65个单位距离时，斜率为：4.64600
# 偏移0.65个单位距离时，斜率为：4.64500
# 偏移0.64个单位距离时，斜率为：4.64400
# 偏移0.64个单位距离时，斜率为：4.64300
# 偏移0.64个单位距离时，斜率为：4.64200
# 偏移0.64个单位距离时，斜率为：4.64100
# 偏移0.64个单位距离时，斜率为：4.64000
# 偏移0.64个单位距离时，斜率为：4.63900
# 偏移0.64个单位距离时，斜率为：4.63800
# 偏移0.64个单位距离时，斜率为：4.63700
# 偏移0.64个单位距离时，斜率为：4.63600
# 偏移0.64个单位距离时，斜率为：4.63500
# 偏移0.63个单位距离时，斜率为：4.63400
# 偏移0.63个单位距离时，斜率为：4.63300
# 偏移0.63个单位距离时，斜率为：4.63200
# 偏移0.63个单位距离时，斜率为：4.63100
# 偏移0.63个单位距离时，斜率为：4.63000
# 偏移0.63个单位距离时，斜率为：4.62900
# 偏移0.63个单位距离时，斜率为：4.62800
# 偏移0.63个单位距离时，斜率为：4.62700
# 偏移0.63个单位距离时，斜率为：4.62600
# 偏移0.62个单位距离时，斜率为：4.62500
# 偏移0.62个单位距离时，斜率为：4.62400
# 偏移0.62个单位距离时，斜率为：4.62300
# 偏移0.62个单位距离时，斜率为：4.62200
# 偏移0.62个单位距离时，斜率为：4.62100
# 偏移0.62个单位距离时，斜率为：4.62000
# 偏移0.62个单位距离时，斜率为：4.61900
# 偏移0.62个单位距离时，斜率为：4.61800
# 偏移0.62个单位距离时，斜率为：4.61700
# 偏移0.62个单位距离时，斜率为：4.61600
# 偏移0.61个单位距离时，斜率为：4.61500
# 偏移0.61个单位距离时，斜率为：4.61400
# 偏移0.61个单位距离时，斜率为：4.61300
# 偏移0.61个单位距离时，斜率为：4.61200
# 偏移0.61个单位距离时，斜率为：4.61100
# 偏移0.61个单位距离时，斜率为：4.61000
# 偏移0.61个单位距离时，斜率为：4.60900
# 偏移0.61个单位距离时，斜率为：4.60800
# 偏移0.61个单位距离时，斜率为：4.60700
# 偏移0.61个单位距离时，斜率为：4.60600
# 偏移0.60个单位距离时，斜率为：4.60500
# 偏移0.60个单位距离时，斜率为：4.60400
# 偏移0.60个单位距离时，斜率为：4.60300
# 偏移0.60个单位距离时，斜率为：4.60200
# 偏移0.60个单位距离时，斜率为：4.60100
# 偏移0.60个单位距离时，斜率为：4.60000
# 偏移0.60个单位距离时，斜率为：4.59900
# 偏移0.60个单位距离时，斜率为：4.59800
# 偏移0.60个单位距离时，斜率为：4.59700
# 偏移0.60个单位距离时，斜率为：4.59600
# 偏移0.59个单位距离时，斜率为：4.59500
# 偏移0.59个单位距离时，斜率为：4.59400
# 偏移0.59个单位距离时，斜率为：4.59300
# 偏移0.59个单位距离时，斜率为：4.59200
# 偏移0.59个单位距离时，斜率为：4.59100
# 偏移0.59个单位距离时，斜率为：4.59000
# 偏移0.59个单位距离时，斜率为：4.58900
# 偏移0.59个单位距离时，斜率为：4.58800
# 偏移0.59个单位距离时，斜率为：4.58700
# 偏移0.59个单位距离时，斜率为：4.58600
# 偏移0.58个单位距离时，斜率为：4.58500
# 偏移0.58个单位距离时，斜率为：4.58400
# 偏移0.58个单位距离时，斜率为：4.58300
# 偏移0.58个单位距离时，斜率为：4.58200
# 偏移0.58个单位距离时，斜率为：4.58100
# 偏移0.58个单位距离时，斜率为：4.58000
# 偏移0.58个单位距离时，斜率为：4.57900
# 偏移0.58个单位距离时，斜率为：4.57800
# 偏移0.58个单位距离时，斜率为：4.57700
# 偏移0.58个单位距离时，斜率为：4.57600
# 偏移0.57个单位距离时，斜率为：4.57500
# 偏移0.57个单位距离时，斜率为：4.57400
# 偏移0.57个单位距离时，斜率为：4.57300
# 偏移0.57个单位距离时，斜率为：4.57200
# 偏移0.57个单位距离时，斜率为：4.57100
# 偏移0.57个单位距离时，斜率为：4.57000
# 偏移0.57个单位距离时，斜率为：4.56900
# 偏移0.57个单位距离时，斜率为：4.56800
# 偏移0.57个单位距离时，斜率为：4.56700
# 偏移0.57个单位距离时，斜率为：4.56600
# 偏移0.56个单位距离时，斜率为：4.56500
# 偏移0.56个单位距离时，斜率为：4.56400
# 偏移0.56个单位距离时，斜率为：4.56300
# 偏移0.56个单位距离时，斜率为：4.56200
# 偏移0.56个单位距离时，斜率为：4.56100
# 偏移0.56个单位距离时，斜率为：4.56000
# 偏移0.56个单位距离时，斜率为：4.55900
# 偏移0.56个单位距离时，斜率为：4.55800
# 偏移0.56个单位距离时，斜率为：4.55700
# 偏移0.56个单位距离时，斜率为：4.55600
# 偏移0.55个单位距离时，斜率为：4.55500
# 偏移0.55个单位距离时，斜率为：4.55400
# 偏移0.55个单位距离时，斜率为：4.55300
# 偏移0.55个单位距离时，斜率为：4.55200
# 偏移0.55个单位距离时，斜率为：4.55100
# 偏移0.55个单位距离时，斜率为：4.55000
# 偏移0.55个单位距离时，斜率为：4.54900
# 偏移0.55个单位距离时，斜率为：4.54800
# 偏移0.55个单位距离时，斜率为：4.54700
# 偏移0.55个单位距离时，斜率为：4.54600
# 偏移0.54个单位距离时，斜率为：4.54500
# 偏移0.54个单位距离时，斜率为：4.54400
# 偏移0.54个单位距离时，斜率为：4.54300
# 偏移0.54个单位距离时，斜率为：4.54200
# 偏移0.54个单位距离时，斜率为：4.54100
# 偏移0.54个单位距离时，斜率为：4.54000
# 偏移0.54个单位距离时，斜率为：4.53900
# 偏移0.54个单位距离时，斜率为：4.53800
# 偏移0.54个单位距离时，斜率为：4.53700
# 偏移0.54个单位距离时，斜率为：4.53600
# 偏移0.53个单位距离时，斜率为：4.53500
# 偏移0.53个单位距离时，斜率为：4.53400
# 偏移0.53个单位距离时，斜率为：4.53300
# 偏移0.53个单位距离时，斜率为：4.53200
# 偏移0.53个单位距离时，斜率为：4.53100
# 偏移0.53个单位距离时，斜率为：4.53000
# 偏移0.53个单位距离时，斜率为：4.52900
# 偏移0.53个单位距离时，斜率为：4.52800
# 偏移0.53个单位距离时，斜率为：4.52700
# 偏移0.53个单位距离时，斜率为：4.52600
# 偏移0.52个单位距离时，斜率为：4.52500
# 偏移0.52个单位距离时，斜率为：4.52400
# 偏移0.52个单位距离时，斜率为：4.52300
# 偏移0.52个单位距离时，斜率为：4.52200
# 偏移0.52个单位距离时，斜率为：4.52100
# 偏移0.52个单位距离时，斜率为：4.52000
# 偏移0.52个单位距离时，斜率为：4.51900
# 偏移0.52个单位距离时，斜率为：4.51800
# 偏移0.52个单位距离时，斜率为：4.51700
# 偏移0.52个单位距离时，斜率为：4.51600
# 偏移0.52个单位距离时，斜率为：4.51500
# 偏移0.51个单位距离时，斜率为：4.51400
# 偏移0.51个单位距离时，斜率为：4.51300
# 偏移0.51个单位距离时，斜率为：4.51200
# 偏移0.51个单位距离时，斜率为：4.51100
# 偏移0.51个单位距离时，斜率为：4.51000
# 偏移0.51个单位距离时，斜率为：4.50900
# 偏移0.51个单位距离时，斜率为：4.50800
# 偏移0.51个单位距离时，斜率为：4.50700
# 偏移0.51个单位距离时，斜率为：4.50600
# 偏移0.51个单位距离时，斜率为：4.50500
# 偏移0.50个单位距离时，斜率为：4.50400
# 偏移0.50个单位距离时，斜率为：4.50300
# 偏移0.50个单位距离时，斜率为：4.50200
# 偏移0.50个单位距离时，斜率为：4.50100
# 偏移0.50个单位距离时，斜率为：4.50000
# 偏移0.50个单位距离时，斜率为：4.49900
# 偏移0.50个单位距离时，斜率为：4.49800
# 偏移0.50个单位距离时，斜率为：4.49700
# 偏移0.50个单位距离时，斜率为：4.49600
# 偏移0.49个单位距离时，斜率为：4.49500
# 偏移0.49个单位距离时，斜率为：4.49400
# 偏移0.49个单位距离时，斜率为：4.49300
# 偏移0.49个单位距离时，斜率为：4.49200
# 偏移0.49个单位距离时，斜率为：4.49100
# 偏移0.49个单位距离时，斜率为：4.49000
# 偏移0.49个单位距离时，斜率为：4.48900
# 偏移0.49个单位距离时，斜率为：4.48800
# 偏移0.49个单位距离时，斜率为：4.48700
# 偏移0.49个单位距离时，斜率为：4.48600
# 偏移0.48个单位距离时，斜率为：4.48500
# 偏移0.48个单位距离时，斜率为：4.48400
# 偏移0.48个单位距离时，斜率为：4.48300
# 偏移0.48个单位距离时，斜率为：4.48200
# 偏移0.48个单位距离时，斜率为：4.48100
# 偏移0.48个单位距离时，斜率为：4.48000
# 偏移0.48个单位距离时，斜率为：4.47900
# 偏移0.48个单位距离时，斜率为：4.47800
# 偏移0.48个单位距离时，斜率为：4.47700
# 偏移0.48个单位距离时，斜率为：4.47600
# 偏移0.47个单位距离时，斜率为：4.47500
# 偏移0.47个单位距离时，斜率为：4.47400
# 偏移0.47个单位距离时，斜率为：4.47300
# 偏移0.47个单位距离时，斜率为：4.47200
# 偏移0.47个单位距离时，斜率为：4.47100
# 偏移0.47个单位距离时，斜率为：4.47000
# 偏移0.47个单位距离时，斜率为：4.46900
# 偏移0.47个单位距离时，斜率为：4.46800
# 偏移0.47个单位距离时，斜率为：4.46700
# 偏移0.47个单位距离时，斜率为：4.46600
# 偏移0.46个单位距离时，斜率为：4.46500
# 偏移0.46个单位距离时，斜率为：4.46400
# 偏移0.46个单位距离时，斜率为：4.46300
# 偏移0.46个单位距离时，斜率为：4.46200
# 偏移0.46个单位距离时，斜率为：4.46100
# 偏移0.46个单位距离时，斜率为：4.46000
# 偏移0.46个单位距离时，斜率为：4.45900
# 偏移0.46个单位距离时，斜率为：4.45800
# 偏移0.46个单位距离时，斜率为：4.45700
# 偏移0.46个单位距离时，斜率为：4.45600
# 偏移0.45个单位距离时，斜率为：4.45500
# 偏移0.45个单位距离时，斜率为：4.45400
# 偏移0.45个单位距离时，斜率为：4.45300
# 偏移0.45个单位距离时，斜率为：4.45200
# 偏移0.45个单位距离时，斜率为：4.45100
# 偏移0.45个单位距离时，斜率为：4.45000
# 偏移0.45个单位距离时，斜率为：4.44900
# 偏移0.45个单位距离时，斜率为：4.44800
# 偏移0.45个单位距离时，斜率为：4.44700
# 偏移0.45个单位距离时，斜率为：4.44600
# 偏移0.44个单位距离时，斜率为：4.44500
# 偏移0.44个单位距离时，斜率为：4.44400
# 偏移0.44个单位距离时，斜率为：4.44300
# 偏移0.44个单位距离时，斜率为：4.44200
# 偏移0.44个单位距离时，斜率为：4.44100
# 偏移0.44个单位距离时，斜率为：4.44000
# 偏移0.44个单位距离时，斜率为：4.43900
# 偏移0.44个单位距离时，斜率为：4.43800
# 偏移0.44个单位距离时，斜率为：4.43700
# 偏移0.44个单位距离时，斜率为：4.43600
# 偏移0.43个单位距离时，斜率为：4.43500
# 偏移0.43个单位距离时，斜率为：4.43400
# 偏移0.43个单位距离时，斜率为：4.43300
# 偏移0.43个单位距离时，斜率为：4.43200
# 偏移0.43个单位距离时，斜率为：4.43100
# 偏移0.43个单位距离时，斜率为：4.43000
# 偏移0.43个单位距离时，斜率为：4.42900
# 偏移0.43个单位距离时，斜率为：4.42800
# 偏移0.43个单位距离时，斜率为：4.42700
# 偏移0.43个单位距离时，斜率为：4.42600
# 偏移0.42个单位距离时，斜率为：4.42500
# 偏移0.42个单位距离时，斜率为：4.42400
# 偏移0.42个单位距离时，斜率为：4.42300
# 偏移0.42个单位距离时，斜率为：4.42200
# 偏移0.42个单位距离时，斜率为：4.42100
# 偏移0.42个单位距离时，斜率为：4.42000
# 偏移0.42个单位距离时，斜率为：4.41900
# 偏移0.42个单位距离时，斜率为：4.41800
# 偏移0.42个单位距离时，斜率为：4.41700
# 偏移0.42个单位距离时，斜率为：4.41600
# 偏移0.42个单位距离时，斜率为：4.41500
# 偏移0.41个单位距离时，斜率为：4.41400
# 偏移0.41个单位距离时，斜率为：4.41300
# 偏移0.41个单位距离时，斜率为：4.41200
# 偏移0.41个单位距离时，斜率为：4.41100
# 偏移0.41个单位距离时，斜率为：4.41000
# 偏移0.41个单位距离时，斜率为：4.40900
# 偏移0.41个单位距离时，斜率为：4.40800
# 偏移0.41个单位距离时，斜率为：4.40700
# 偏移0.41个单位距离时，斜率为：4.40600
# 偏移0.41个单位距离时，斜率为：4.40500
# 偏移0.40个单位距离时，斜率为：4.40400
# 偏移0.40个单位距离时，斜率为：4.40300
# 偏移0.40个单位距离时，斜率为：4.40200
# 偏移0.40个单位距离时，斜率为：4.40100
# 偏移0.40个单位距离时，斜率为：4.40000
# 偏移0.40个单位距离时，斜率为：4.39900
# 偏移0.40个单位距离时，斜率为：4.39800
# 偏移0.40个单位距离时，斜率为：4.39700
# 偏移0.40个单位距离时，斜率为：4.39600
# 偏移0.40个单位距离时，斜率为：4.39500
# 偏移0.39个单位距离时，斜率为：4.39400
# 偏移0.39个单位距离时，斜率为：4.39300
# 偏移0.39个单位距离时，斜率为：4.39200
# 偏移0.39个单位距离时，斜率为：4.39100
# 偏移0.39个单位距离时，斜率为：4.39000
# 偏移0.39个单位距离时，斜率为：4.38900
# 偏移0.39个单位距离时，斜率为：4.38800
# 偏移0.39个单位距离时，斜率为：4.38700
# 偏移0.39个单位距离时，斜率为：4.38600
# 偏移0.39个单位距离时，斜率为：4.38500
# 偏移0.38个单位距离时，斜率为：4.38400
# 偏移0.38个单位距离时，斜率为：4.38300
# 偏移0.38个单位距离时，斜率为：4.38200
# 偏移0.38个单位距离时，斜率为：4.38100
# 偏移0.38个单位距离时，斜率为：4.38000
# 偏移0.38个单位距离时，斜率为：4.37900
# 偏移0.38个单位距离时，斜率为：4.37800
# 偏移0.38个单位距离时，斜率为：4.37700
# 偏移0.38个单位距离时，斜率为：4.37600
# 偏移0.38个单位距离时，斜率为：4.37500
# 偏移0.37个单位距离时，斜率为：4.37400
# 偏移0.37个单位距离时，斜率为：4.37300
# 偏移0.37个单位距离时，斜率为：4.37200
# 偏移0.37个单位距离时，斜率为：4.37100
# 偏移0.37个单位距离时，斜率为：4.37000
# 偏移0.37个单位距离时，斜率为：4.36900
# 偏移0.37个单位距离时，斜率为：4.36800
# 偏移0.37个单位距离时，斜率为：4.36700
# 偏移0.37个单位距离时，斜率为：4.36600
# 偏移0.36个单位距离时，斜率为：4.36500
# 偏移0.36个单位距离时，斜率为：4.36400
# 偏移0.36个单位距离时，斜率为：4.36300
# 偏移0.36个单位距离时，斜率为：4.36200
# 偏移0.36个单位距离时，斜率为：4.36100
# 偏移0.36个单位距离时，斜率为：4.36000
# 偏移0.36个单位距离时，斜率为：4.35900
# 偏移0.36个单位距离时，斜率为：4.35800
# 偏移0.36个单位距离时，斜率为：4.35700
# 偏移0.36个单位距离时，斜率为：4.35600
# 偏移0.35个单位距离时，斜率为：4.35500
# 偏移0.35个单位距离时，斜率为：4.35400
# 偏移0.35个单位距离时，斜率为：4.35300
# 偏移0.35个单位距离时，斜率为：4.35200
# 偏移0.35个单位距离时，斜率为：4.35100
# 偏移0.35个单位距离时，斜率为：4.35000
# 偏移0.35个单位距离时，斜率为：4.34900
# 偏移0.35个单位距离时，斜率为：4.34800
# 偏移0.35个单位距离时，斜率为：4.34700
# 偏移0.35个单位距离时，斜率为：4.34600
# 偏移0.34个单位距离时，斜率为：4.34500
# 偏移0.34个单位距离时，斜率为：4.34400
# 偏移0.34个单位距离时，斜率为：4.34300
# 偏移0.34个单位距离时，斜率为：4.34200
# 偏移0.34个单位距离时，斜率为：4.34100
# 偏移0.34个单位距离时，斜率为：4.34000
# 偏移0.34个单位距离时，斜率为：4.33900
# 偏移0.34个单位距离时，斜率为：4.33800
# 偏移0.34个单位距离时，斜率为：4.33700
# 偏移0.34个单位距离时，斜率为：4.33600
# 偏移0.33个单位距离时，斜率为：4.33500
# 偏移0.33个单位距离时，斜率为：4.33400
# 偏移0.33个单位距离时，斜率为：4.33300
# 偏移0.33个单位距离时，斜率为：4.33200
# 偏移0.33个单位距离时，斜率为：4.33100
# 偏移0.33个单位距离时，斜率为：4.33000
# 偏移0.33个单位距离时，斜率为：4.32900
# 偏移0.33个单位距离时，斜率为：4.32800
# 偏移0.33个单位距离时，斜率为：4.32700
# 偏移0.33个单位距离时，斜率为：4.32600
# 偏移0.32个单位距离时，斜率为：4.32500
# 偏移0.32个单位距离时，斜率为：4.32400
# 偏移0.32个单位距离时，斜率为：4.32300
# 偏移0.32个单位距离时，斜率为：4.32200
# 偏移0.32个单位距离时，斜率为：4.32100
# 偏移0.32个单位距离时，斜率为：4.32000
# 偏移0.32个单位距离时，斜率为：4.31900
# 偏移0.32个单位距离时，斜率为：4.31800
# 偏移0.32个单位距离时，斜率为：4.31700
# 偏移0.32个单位距离时，斜率为：4.31600
# 偏移0.31个单位距离时，斜率为：4.31500
# 偏移0.31个单位距离时，斜率为：4.31400
# 偏移0.31个单位距离时，斜率为：4.31300
# 偏移0.31个单位距离时，斜率为：4.31200
# 偏移0.31个单位距离时，斜率为：4.31100
# 偏移0.31个单位距离时，斜率为：4.31000
# 偏移0.31个单位距离时，斜率为：4.30900
# 偏移0.31个单位距离时，斜率为：4.30800
# 偏移0.31个单位距离时，斜率为：4.30700
# 偏移0.31个单位距离时，斜率为：4.30600
# 偏移0.30个单位距离时，斜率为：4.30500
# 偏移0.30个单位距离时，斜率为：4.30400
# 偏移0.30个单位距离时，斜率为：4.30300
# 偏移0.30个单位距离时，斜率为：4.30200
# 偏移0.30个单位距离时，斜率为：4.30100
# 偏移0.30个单位距离时，斜率为：4.30000
# 偏移0.30个单位距离时，斜率为：4.29900
# 偏移0.30个单位距离时，斜率为：4.29800
# 偏移0.30个单位距离时，斜率为：4.29700
# 偏移0.30个单位距离时，斜率为：4.29600
# 偏移0.30个单位距离时，斜率为：4.29500
# 偏移0.29个单位距离时，斜率为：4.29400
# 偏移0.29个单位距离时，斜率为：4.29300
# 偏移0.29个单位距离时，斜率为：4.29200
# 偏移0.29个单位距离时，斜率为：4.29100
# 偏移0.29个单位距离时，斜率为：4.29000
# 偏移0.29个单位距离时，斜率为：4.28900
# 偏移0.29个单位距离时，斜率为：4.28800
# 偏移0.29个单位距离时，斜率为：4.28700
# 偏移0.29个单位距离时，斜率为：4.28600
# 偏移0.29个单位距离时，斜率为：4.28500
# 偏移0.28个单位距离时，斜率为：4.28400
# 偏移0.28个单位距离时，斜率为：4.28300
# 偏移0.28个单位距离时，斜率为：4.28200
# 偏移0.28个单位距离时，斜率为：4.28100
# 偏移0.28个单位距离时，斜率为：4.28000
# 偏移0.28个单位距离时，斜率为：4.27900
# 偏移0.28个单位距离时，斜率为：4.27800
# 偏移0.28个单位距离时，斜率为：4.27700
# 偏移0.28个单位距离时，斜率为：4.27600
# 偏移0.28个单位距离时，斜率为：4.27500
# 偏移0.27个单位距离时，斜率为：4.27400
# 偏移0.27个单位距离时，斜率为：4.27300
# 偏移0.27个单位距离时，斜率为：4.27200
# 偏移0.27个单位距离时，斜率为：4.27100
# 偏移0.27个单位距离时，斜率为：4.27000
# 偏移0.27个单位距离时，斜率为：4.26900
# 偏移0.27个单位距离时，斜率为：4.26800
# 偏移0.27个单位距离时，斜率为：4.26700
# 偏移0.27个单位距离时，斜率为：4.26600
# 偏移0.27个单位距离时，斜率为：4.26500
# 偏移0.26个单位距离时，斜率为：4.26400
# 偏移0.26个单位距离时，斜率为：4.26300
# 偏移0.26个单位距离时，斜率为：4.26200
# 偏移0.26个单位距离时，斜率为：4.26100
# 偏移0.26个单位距离时，斜率为：4.26000
# 偏移0.26个单位距离时，斜率为：4.25900
# 偏移0.26个单位距离时，斜率为：4.25800
# 偏移0.26个单位距离时，斜率为：4.25700
# 偏移0.26个单位距离时，斜率为：4.25600
# 偏移0.26个单位距离时，斜率为：4.25500
# 偏移0.25个单位距离时，斜率为：4.25400
# 偏移0.25个单位距离时，斜率为：4.25300
# 偏移0.25个单位距离时，斜率为：4.25200
# 偏移0.25个单位距离时，斜率为：4.25100
# 偏移0.25个单位距离时，斜率为：4.25000
# 偏移0.25个单位距离时，斜率为：4.24900
# 偏移0.25个单位距离时，斜率为：4.24800
# 偏移0.25个单位距离时，斜率为：4.24700
# 偏移0.25个单位距离时，斜率为：4.24600
# 偏移0.24个单位距离时，斜率为：4.24500
# 偏移0.24个单位距离时，斜率为：4.24400
# 偏移0.24个单位距离时，斜率为：4.24300
# 偏移0.24个单位距离时，斜率为：4.24200
# 偏移0.24个单位距离时，斜率为：4.24100
# 偏移0.24个单位距离时，斜率为：4.24000
# 偏移0.24个单位距离时，斜率为：4.23900
# 偏移0.24个单位距离时，斜率为：4.23800
# 偏移0.24个单位距离时，斜率为：4.23700
# 偏移0.24个单位距离时，斜率为：4.23600
# 偏移0.23个单位距离时，斜率为：4.23500
# 偏移0.23个单位距离时，斜率为：4.23400
# 偏移0.23个单位距离时，斜率为：4.23300
# 偏移0.23个单位距离时，斜率为：4.23200
# 偏移0.23个单位距离时，斜率为：4.23100
# 偏移0.23个单位距离时，斜率为：4.23000
# 偏移0.23个单位距离时，斜率为：4.22900
# 偏移0.23个单位距离时，斜率为：4.22800
# 偏移0.23个单位距离时，斜率为：4.22700
# 偏移0.23个单位距离时，斜率为：4.22600
# 偏移0.22个单位距离时，斜率为：4.22500
# 偏移0.22个单位距离时，斜率为：4.22400
# 偏移0.22个单位距离时，斜率为：4.22300
# 偏移0.22个单位距离时，斜率为：4.22200
# 偏移0.22个单位距离时，斜率为：4.22100
# 偏移0.22个单位距离时，斜率为：4.22000
# 偏移0.22个单位距离时，斜率为：4.21900
# 偏移0.22个单位距离时，斜率为：4.21800
# 偏移0.22个单位距离时，斜率为：4.21700
# 偏移0.22个单位距离时，斜率为：4.21600
# 偏移0.21个单位距离时，斜率为：4.21500
# 偏移0.21个单位距离时，斜率为：4.21400
# 偏移0.21个单位距离时，斜率为：4.21300
# 偏移0.21个单位距离时，斜率为：4.21200
# 偏移0.21个单位距离时，斜率为：4.21100
# 偏移0.21个单位距离时，斜率为：4.21000
# 偏移0.21个单位距离时，斜率为：4.20900
# 偏移0.21个单位距离时，斜率为：4.20800
# 偏移0.21个单位距离时，斜率为：4.20700
# 偏移0.21个单位距离时，斜率为：4.20600
# 偏移0.20个单位距离时，斜率为：4.20500
# 偏移0.20个单位距离时，斜率为：4.20400
# 偏移0.20个单位距离时，斜率为：4.20300
# 偏移0.20个单位距离时，斜率为：4.20200
# 偏移0.20个单位距离时，斜率为：4.20100
# 偏移0.20个单位距离时，斜率为：4.20000
# 偏移0.20个单位距离时，斜率为：4.19900
# 偏移0.20个单位距离时，斜率为：4.19800
# 偏移0.20个单位距离时，斜率为：4.19700
# 偏移0.20个单位距离时，斜率为：4.19600
# 偏移0.19个单位距离时，斜率为：4.19500
# 偏移0.19个单位距离时，斜率为：4.19400
# 偏移0.19个单位距离时，斜率为：4.19300
# 偏移0.19个单位距离时，斜率为：4.19200
# 偏移0.19个单位距离时，斜率为：4.19100
# 偏移0.19个单位距离时，斜率为：4.19000
# 偏移0.19个单位距离时，斜率为：4.18900
# 偏移0.19个单位距离时，斜率为：4.18800
# 偏移0.19个单位距离时，斜率为：4.18700
# 偏移0.19个单位距离时，斜率为：4.18600
# 偏移0.18个单位距离时，斜率为：4.18500
# 偏移0.18个单位距离时，斜率为：4.18400
# 偏移0.18个单位距离时，斜率为：4.18300
# 偏移0.18个单位距离时，斜率为：4.18200
# 偏移0.18个单位距离时，斜率为：4.18100
# 偏移0.18个单位距离时，斜率为：4.18000
# 偏移0.18个单位距离时，斜率为：4.17900
# 偏移0.18个单位距离时，斜率为：4.17800
# 偏移0.18个单位距离时，斜率为：4.17700
# 偏移0.18个单位距离时，斜率为：4.17600
# 偏移0.17个单位距离时，斜率为：4.17500
# 偏移0.17个单位距离时，斜率为：4.17400
# 偏移0.17个单位距离时，斜率为：4.17300
# 偏移0.17个单位距离时，斜率为：4.17200
# 偏移0.17个单位距离时，斜率为：4.17100
# 偏移0.17个单位距离时，斜率为：4.17000
# 偏移0.17个单位距离时，斜率为：4.16900
# 偏移0.17个单位距离时，斜率为：4.16800
# 偏移0.17个单位距离时，斜率为：4.16700
# 偏移0.17个单位距离时，斜率为：4.16600
# 偏移0.17个单位距离时，斜率为：4.16500
# 偏移0.16个单位距离时，斜率为：4.16400
# 偏移0.16个单位距离时，斜率为：4.16300
# 偏移0.16个单位距离时，斜率为：4.16200
# 偏移0.16个单位距离时，斜率为：4.16100
# 偏移0.16个单位距离时，斜率为：4.16000
# 偏移0.16个单位距离时，斜率为：4.15900
# 偏移0.16个单位距离时，斜率为：4.15800
# 偏移0.16个单位距离时，斜率为：4.15700
# 偏移0.16个单位距离时，斜率为：4.15600
# 偏移0.16个单位距离时，斜率为：4.15500
# 偏移0.15个单位距离时，斜率为：4.15400
# 偏移0.15个单位距离时，斜率为：4.15300
# 偏移0.15个单位距离时，斜率为：4.15200
# 偏移0.15个单位距离时，斜率为：4.15100
# 偏移0.15个单位距离时，斜率为：4.15000
# 偏移0.15个单位距离时，斜率为：4.14900
# 偏移0.15个单位距离时，斜率为：4.14800
# 偏移0.15个单位距离时，斜率为：4.14700
# 偏移0.15个单位距离时，斜率为：4.14600
# 偏移0.15个单位距离时，斜率为：4.14500
# 偏移0.14个单位距离时，斜率为：4.14400
# 偏移0.14个单位距离时，斜率为：4.14300
# 偏移0.14个单位距离时，斜率为：4.14200
# 偏移0.14个单位距离时，斜率为：4.14100
# 偏移0.14个单位距离时，斜率为：4.14000
# 偏移0.14个单位距离时，斜率为：4.13900
# 偏移0.14个单位距离时，斜率为：4.13800
# 偏移0.14个单位距离时，斜率为：4.13700
# 偏移0.14个单位距离时，斜率为：4.13600
# 偏移0.14个单位距离时，斜率为：4.13500
# 偏移0.13个单位距离时，斜率为：4.13400
# 偏移0.13个单位距离时，斜率为：4.13300
# 偏移0.13个单位距离时，斜率为：4.13200
# 偏移0.13个单位距离时，斜率为：4.13100
# 偏移0.13个单位距离时，斜率为：4.13000
# 偏移0.13个单位距离时，斜率为：4.12900
# 偏移0.13个单位距离时，斜率为：4.12800
# 偏移0.13个单位距离时，斜率为：4.12700
# 偏移0.13个单位距离时，斜率为：4.12600
# 偏移0.12个单位距离时，斜率为：4.12500
# 偏移0.12个单位距离时，斜率为：4.12400
# 偏移0.12个单位距离时，斜率为：4.12300
# 偏移0.12个单位距离时，斜率为：4.12200
# 偏移0.12个单位距离时，斜率为：4.12100
# 偏移0.12个单位距离时，斜率为：4.12000
# 偏移0.12个单位距离时，斜率为：4.11900
# 偏移0.12个单位距离时，斜率为：4.11800
# 偏移0.12个单位距离时，斜率为：4.11700
# 偏移0.12个单位距离时，斜率为：4.11600
# 偏移0.11个单位距离时，斜率为：4.11500
# 偏移0.11个单位距离时，斜率为：4.11400
# 偏移0.11个单位距离时，斜率为：4.11300
# 偏移0.11个单位距离时，斜率为：4.11200
# 偏移0.11个单位距离时，斜率为：4.11100
# 偏移0.11个单位距离时，斜率为：4.11000
# 偏移0.11个单位距离时，斜率为：4.10900
# 偏移0.11个单位距离时，斜率为：4.10800
# 偏移0.11个单位距离时，斜率为：4.10700
# 偏移0.11个单位距离时，斜率为：4.10600
# 偏移0.10个单位距离时，斜率为：4.10500
# 偏移0.10个单位距离时，斜率为：4.10400
# 偏移0.10个单位距离时，斜率为：4.10300
# 偏移0.10个单位距离时，斜率为：4.10200
# 偏移0.10个单位距离时，斜率为：4.10100
# 偏移0.10个单位距离时，斜率为：4.10000
# 偏移0.10个单位距离时，斜率为：4.09900
# 偏移0.10个单位距离时，斜率为：4.09800
# 偏移0.10个单位距离时，斜率为：4.09700
# 偏移0.10个单位距离时，斜率为：4.09600
# 偏移0.09个单位距离时，斜率为：4.09500
# 偏移0.09个单位距离时，斜率为：4.09400
# 偏移0.09个单位距离时，斜率为：4.09300
# 偏移0.09个单位距离时，斜率为：4.09200
# 偏移0.09个单位距离时，斜率为：4.09100
# 偏移0.09个单位距离时，斜率为：4.09000
# 偏移0.09个单位距离时，斜率为：4.08900
# 偏移0.09个单位距离时，斜率为：4.08800
# 偏移0.09个单位距离时，斜率为：4.08700
# 偏移0.09个单位距离时，斜率为：4.08600
# 偏移0.08个单位距离时，斜率为：4.08500
# 偏移0.08个单位距离时，斜率为：4.08400
# 偏移0.08个单位距离时，斜率为：4.08300
# 偏移0.08个单位距离时，斜率为：4.08200
# 偏移0.08个单位距离时，斜率为：4.08100
# 偏移0.08个单位距离时，斜率为：4.08000
# 偏移0.08个单位距离时，斜率为：4.07900
# 偏移0.08个单位距离时，斜率为：4.07800
# 偏移0.08个单位距离时，斜率为：4.07700
# 偏移0.08个单位距离时，斜率为：4.07600
# 偏移0.07个单位距离时，斜率为：4.07500
# 偏移0.07个单位距离时，斜率为：4.07400
# 偏移0.07个单位距离时，斜率为：4.07300
# 偏移0.07个单位距离时，斜率为：4.07200
# 偏移0.07个单位距离时，斜率为：4.07100
# 偏移0.07个单位距离时，斜率为：4.07000
# 偏移0.07个单位距离时，斜率为：4.06900
# 偏移0.07个单位距离时，斜率为：4.06800
# 偏移0.07个单位距离时，斜率为：4.06700
# 偏移0.07个单位距离时，斜率为：4.06600
# 偏移0.06个单位距离时，斜率为：4.06500
# 偏移0.06个单位距离时，斜率为：4.06400
# 偏移0.06个单位距离时，斜率为：4.06300
# 偏移0.06个单位距离时，斜率为：4.06200
# 偏移0.06个单位距离时，斜率为：4.06100
# 偏移0.06个单位距离时，斜率为：4.06000
# 偏移0.06个单位距离时，斜率为：4.05900
# 偏移0.06个单位距离时，斜率为：4.05800
# 偏移0.06个单位距离时，斜率为：4.05700
# 偏移0.06个单位距离时，斜率为：4.05600
# 偏移0.05个单位距离时，斜率为：4.05500
# 偏移0.05个单位距离时，斜率为：4.05400
# 偏移0.05个单位距离时，斜率为：4.05300
# 偏移0.05个单位距离时，斜率为：4.05200
# 偏移0.05个单位距离时，斜率为：4.05100
# 偏移0.05个单位距离时，斜率为：4.05000
# 偏移0.05个单位距离时，斜率为：4.04900
# 偏移0.05个单位距离时，斜率为：4.04800
# 偏移0.05个单位距离时，斜率为：4.04700
# 偏移0.05个单位距离时，斜率为：4.04600
# 偏移0.04个单位距离时，斜率为：4.04500
# 偏移0.04个单位距离时，斜率为：4.04400
# 偏移0.04个单位距离时，斜率为：4.04300
# 偏移0.04个单位距离时，斜率为：4.04200
# 偏移0.04个单位距离时，斜率为：4.04100
# 偏移0.04个单位距离时，斜率为：4.04000
# 偏移0.04个单位距离时，斜率为：4.03900
# 偏移0.04个单位距离时，斜率为：4.03800
# 偏移0.04个单位距离时，斜率为：4.03700
# 偏移0.04个单位距离时，斜率为：4.03600
# 偏移0.04个单位距离时，斜率为：4.03500
# 偏移0.03个单位距离时，斜率为：4.03400
# 偏移0.03个单位距离时，斜率为：4.03300
# 偏移0.03个单位距离时，斜率为：4.03200
# 偏移0.03个单位距离时，斜率为：4.03100
# 偏移0.03个单位距离时，斜率为：4.03000
# 偏移0.03个单位距离时，斜率为：4.02900
# 偏移0.03个单位距离时，斜率为：4.02800
# 偏移0.03个单位距离时，斜率为：4.02700
# 偏移0.03个单位距离时，斜率为：4.02600
# 偏移0.03个单位距离时，斜率为：4.02500
# 偏移0.02个单位距离时，斜率为：4.02400
# 偏移0.02个单位距离时，斜率为：4.02300
# 偏移0.02个单位距离时，斜率为：4.02200
# 偏移0.02个单位距离时，斜率为：4.02100
# 偏移0.02个单位距离时，斜率为：4.02000
# 偏移0.02个单位距离时，斜率为：4.01900
# 偏移0.02个单位距离时，斜率为：4.01800
# 偏移0.02个单位距离时，斜率为：4.01700
# 偏移0.02个单位距离时，斜率为：4.01600
# 偏移0.02个单位距离时，斜率为：4.01500
# 偏移0.01个单位距离时，斜率为：4.01400
# 偏移0.01个单位距离时，斜率为：4.01300
# 偏移0.01个单位距离时，斜率为：4.01200
# 偏移0.01个单位距离时，斜率为：4.01100
# 偏移0.01个单位距离时，斜率为：4.01000
# 偏移0.01个单位距离时，斜率为：4.00900
# 偏移0.01个单位距离时，斜率为：4.00800
# 偏移0.01个单位距离时，斜率为：4.00700
# 偏移0.01个单位距离时，斜率为：4.00600
# 偏移0.01个单位距离时，斜率为：4.00500
# 偏移0.00个单位距离时，斜率为：4.00400
# 偏移0.00个单位距离时，斜率为：4.00300
# 偏移0.00个单位距离时，斜率为：4.00200
# 偏移0.00个单位距离时，斜率为：4.00100

# %%
# 图示

n = np.linspace(-10,10,num = 50)
plt.plot(n,f(n))
plt.xlim(-11,11)
plt.ylim(-10,110)

plt.scatter(2,4)
plt.plot(n,4*n - 4)
# m点切线

# %%
def f(x):
    return 2*x**3 - 5*x**2 +3*x*np.sin(x)+(x**2 +1)/(2*x) - 7

x = np.linspace(0,10,num = 100)
y = f(x)
plt.figure(figsize = (12,6))
#plt.scatter(x,y)
plt.plot(x,y)


def f_(x):
    return 1 - 10*x +6*x**2 -(1+x**2)/(2*x**2) + 3*np.cos(x)*x +3*np.sin(x)

m = 6
ym = f(6)
print(m,ym)
plt.scatter(m,ym)

k = f_(6)
b = ym - m*k

def fk(x):
    return k*x+b

yk = fk(x)
plt.plot(x,yk)
# Out:
# 6 243.05385436575267

# %%
def f2(x):
    return x**3
def f2_(x):
    return 3*x**2
def f2__(x):
    return 6*x
plt.figure(figsize = (12,6))
x = np.linspace(-10,10,num = 50)
y1 = f2(x)
plt.plot(x,y1)
plt.plot(x,f2_(x))
plt.plot(x,f2__(x))
